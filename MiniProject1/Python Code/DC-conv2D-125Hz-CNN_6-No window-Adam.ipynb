# %%
import torch
from torch import Tensor
from torch import nn 
from torch.autograd import Variable
import torch.nn.functional as F
import numpy as np
from utility import *

np.random.seed(seed=7)

# %%
import dlc_bci

train_input_100 , train_target_100 = dlc_bci.load(root = './data_bci_100Hz', download = False)
test_input_100 , test_target_100 = dlc_bci.load(root = './data_bci_100Hz', download = False, train = False)

train_input_1000 , train_target_1000 = dlc_bci.load(root = './data_bci_1000Hz', download = False, one_khz = True)
test_input_1000 , test_target_1000 = dlc_bci.load(root = './data_bci_1000Hz', download = False, train = False, one_khz = True)

print("Train input 100 Hz: {:d}x{:d}x{:d}".format(*(s for s in train_input_100.size())))
print("Train target 100 Hz: {:d}".format(*(s for s in train_target_100.size())))
print("Test input 100 Hz: {:d}x{:d}x{:d}".format(*(s for s in test_input_100.size())))
print("Test target 100 Hz: {:d}".format(*(s for s in test_target_100.size())))
print("")
print("Train input 1000 Hz: {:d}x{:d}x{:d}".format(*(s for s in train_input_1000.size())))
print("Train target 1000 Hz: {:d}".format(*(s for s in train_target_1000.size())))
print("Test input 1000 Hz: {:d}x{:d}x{:d}".format(*(s for s in test_input_1000.size())))
print("Test target 1000 Hz: {:d}".format(*(s for s in test_target_1000.size())))
# Out:
# Train input 100 Hz: 316x28x50
# Train target 100 Hz: 316
# Test input 100 Hz: 100x28x50
# Test target 100 Hz: 100
#
# Train input 1000 Hz: 316x28x500
# Train target 1000 Hz: 316
# Test input 1000 Hz: 100x28x500
# Test target 1000 Hz: 100

# %% [markdown]
# # Network definition

# %% [markdown]
# This conv2d network is more inspired from a classic conv2d net that is used for image recognition

# %%
from models import *

# %%
def compute_nb_errors(model, data_input, data_target, batch_size):
    nb_errors = 0
    Ndata = len(data_input[:, 0, 0, 0])
    model.eval()
    print('data_target', data_target.shape)
    print('data_input', data_input.shape)
    
    for b_start in range(0, Ndata, batch_size):
        bsize_eff = batch_size - max(0, b_start+batch_size-Ndata)  # boundary case
        batch_output = model.forward(data_input.narrow(0, b_start, bsize_eff))  # is Variable if data_input is Variable
        if len(list(batch_output.size()))>1 and batch_output.size(1) > 1:
            # as many ouputs as there are classes => select maximum output
            nb_err_batch = (batch_output.max(1)[1] != data_target.narrow(0, b_start, bsize_eff)).long().sum()
            # overflow problem if conversion to Long Int not performed, treated as short 1-byte int otherwise!!
        else:
            # output is a scalar in [0, 1]
            nb_err_batch = batch_output.round().sub(data_target.narrow(0, b_start, bsize_eff)).sign().abs().sum()
        
        nb_errors += nb_err_batch
    if isinstance(nb_errors, Variable):
        nb_errors = nb_errors.data[0]
    return nb_errors

# %% [markdown]
# # Preprocessing and Data Augmentation

# %%
import numpy as np

preprocessed_input_train, preprocessed_input_validation, preprocessed_input_train_target, preprocessed_input_validation_target, kept_channels_idx = preprocessing_train(train_input_1000, train_target_1000, subsampling_frequency='125Hz', window=False,denoize=False, addGaussianNoise=False, reduceChannels=False, cutEnd = False)
preprocessed_input_test, preprocessed_input_test_target  = preprocessing_test(test_input_1000, test_target_1000, kept_channels_idx, subsampling_frequency='125Hz', window=False,denoize = False, reduceChannels=False, cutEnd=False)

#Remove Noise
#preprocessed_input_train = denoisedSignals(preprocessed_input_train)
#preprocessed_input_validation = denoisedSignals(preprocessed_input_validation)
#preprocessed_input_test = denoisedSignals(preprocessed_input_test)
#add random noise
#preprocessed_input_train = whiteNoise(preprocessed_input_train)
#preprocessed_input_validation = whiteNoise(preprocessed_input_validation)
#preprocessed_input_test = whiteNoise(preprocessed_input_test)

print('train', preprocessed_input_train.shape)
print('test', preprocessed_input_test.shape)
print('validation', preprocessed_input_validation.shape)

labels_train = torch.from_numpy(preprocessed_input_train_target)
labels_test = torch.from_numpy(preprocessed_input_test_target)
labels_validation = torch.from_numpy(preprocessed_input_validation_target)

preprocessed_input_train = torch.from_numpy(preprocessed_input_train).float()
preprocessed_input_test = torch.from_numpy(preprocessed_input_test).float()
preprocessed_input_validation = torch.from_numpy(preprocessed_input_validation).float()

Ntrain = len(preprocessed_input_train[:,0,0])
Ntest = len(preprocessed_input_test[:,0,0])
Nvalidation = len(preprocessed_input_validation[:,0,0])

Nchannels = len(preprocessed_input_train[0,:,0])
Nsamples_100 = preprocessed_input_train.size(-1)

print('Ntrain = ', Ntrain)
print('Ntest = ', Ntest)
print('Nvalidation = ', Nvalidation)

train_input = Variable(preprocessed_input_train.view(Ntrain, 1, Nchannels, Nsamples_100))
validation_input = Variable(preprocessed_input_validation.view(Nvalidation, 1, Nchannels, Nsamples_100), requires_grad=False)
test_input = Variable(preprocessed_input_test.contiguous().view(Ntest, 1, Nchannels, Nsamples_100), requires_grad=False)
# Out:
# train (2400, 28, 62)
# test (800, 28, 62)
# validation (128, 28, 62)
# Ntrain =  2400
# Ntest =  800
# Nvalidation =  128

# %% [markdown]
# # Network training and testing
# Non-linearity: elu
#
#
# |criterion | optimizer | lr  | momentum | batch size | Nepochs | Train acc. | Test acc.|
# |----------|-----------|-----|----------|------------|---------|------------|----------|
# | BCE  | Adam  |1e-1 | def. | 15 | 150 | 86.4 | 61.4 |
# | BCE  | Adam  |1e-1 | def. | 20 | 150 | 99.8 | 79.5 |
# | BCE  | SGD   | 1e-2 | 0.85 | 20 | 150 | 98.9  | 61.5 |
# | CE   | Adam  | 1e-2 | def. | 20 | 150 | 98.4  |  70.5 |
# | CE   | SGD   | 1e-2 | 0.85 | 20 | 150 | 99.1 | 75.1 |
#
#
# Non-linearity: ReLU

# %%
import torch.optim as optim
import math

# Train network 
criterion = nn.BCELoss()
#criterion = nn.CrossEntropyLoss()
#criterion = nn.PoissonNLLLoss()
#criterion = nn.BCEWithLogitsLoss()
#criterion = nn.SmoothL1Loss() #interesting ... but does not converge
#criterion = nn.MSELoss() #0.83 but unstable

if isinstance(criterion, nn.CrossEntropyLoss):
    train_target = Variable(labels_train)  # keep long tensors
    validation_target = Variable(labels_validation, requires_grad=False) # convert to float
    test_target = Variable(labels_test, requires_grad=False)
    Noutputs = 2
    
elif isinstance(criterion, nn.NLLLoss):
    train_target = Variable(labels_train)  # keep long tensors
    validation_target = Variable(labels_validation, requires_grad=False) # convert to float
    test_target = Variable(labels_test, requires_grad=False )
    Noutputs = 2
    
else:
    train_target = Variable(labels_train.float()) # convert to float
    validation_target = Variable(labels_validation.float(), requires_grad=False) # convert to float
    test_target = Variable(labels_test.float(), requires_grad=False)
    Noutputs = 1

batch_size = 15
Nbatches = int(math.ceil(Ntrain/batch_size))
Nepochs = 50
seeds = list(range(10))
#seeds = [14,20,21,22,27,46,44,37,31,28]
Nrep = len(seeds)

train_errors = torch.Tensor(Nrep, Nepochs).zero_()
test_errors = torch.Tensor(Nrep, Nepochs).zero_()
validation_errors = torch.Tensor(Nrep, Nepochs).zero_()
ep_loss = torch.Tensor(Nrep, Nepochs).zero_()

for i_rep in range(Nrep):
    
    print('Repetition', seeds[i_rep])
    torch.manual_seed(seeds[i_rep])
    #model = conv2DNet_1(Noutputs) #from classic knowledge of image segmentation  
    #model = conv2DNet_2(Nchannels, Nsamples_100, Noutputs) #from litterature 
    #model = conv2DNet_3(Noutputs) #from PdM
    #model = conv2DNet_4(Noutputs) #from PdM
    #model = conv2DNet_5(Noutputs)
    model = conv2DNet_6(Noutputs)
    #model = conv2DNet_7(Noutputs)
    
    #optimizer = optim.SGD(model.parameters(), lr=1e-3, momentum=0.50)
    optimizer = optim.Adam(model.parameters())
    #optimizer = optim.Adagrad(model.parameters())
    #optimizer = optim.Adamax(model.parameters())
    #optimizer = optim.ASGD(model.parameters())
    #optimizer = optim.RMSprop(model.parameters())
    #optimizer = optim.Rprop(model.parameters())
    
    scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=10, verbose=True)

    for i_ep in range(Nepochs):
        for b_start in range(0, Ntrain, batch_size):
            bsize_eff = batch_size - max(0, b_start+batch_size-Ntrain)  # boundary case
            model.train()
            model.zero_grad()
            output = model(train_input.narrow(0, b_start, bsize_eff))
            batch_loss = criterion(output, train_target.narrow(0, b_start, bsize_eff))            
            ep_loss[i_rep, i_ep] += batch_loss.data[0]
            batch_loss.backward()
            optimizer.step()
        
        scheduler.step(ep_loss[i_rep, i_ep])
        
        nb_train_errs = compute_nb_errors(model, train_input, train_target, batch_size)
        nb_validation_errs = compute_nb_errors(model, validation_input, validation_target, batch_size)
        nb_test_errs = compute_nb_errors(model, test_input, test_target, batch_size)
        
        print("Epoch Number : ", i_ep)
        print("\t Training accuracy: ", (100*(Ntrain-nb_train_errs)/Ntrain))
        print("\t Validation accuracy ",(100*(Nvalidation-nb_validation_errs)/Nvalidation)) 
        print("\t Test accuracy ",(100*(Ntest-nb_test_errs)/Ntest))
        
        print("\t Epoch Loss ", ep_loss[i_rep, i_ep])
        
        train_errors[i_rep, i_ep] = nb_train_errs
        test_errors[i_rep, i_ep] = nb_test_errs
        validation_errors[i_rep, i_ep] = nb_validation_errs
# Out:
# Repetition 0
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  0
# 	 Training accuracy:  89.58333333333333
# 	 Validation accuracy  54.6875
# 	 Test accuracy  72.5
# 	 Epoch Loss  97.12044525146484
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  1
# 	 Training accuracy:  97.70833333333333
# 	 Validation accuracy  69.53125
# 	 Test accuracy  78.0
# 	 Epoch Loss  25.5789794921875
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  2
# 	 Training accuracy:  97.45833333333333
# 	 Validation accuracy  64.0625
# 	 Test accuracy  71.0
# 	 Epoch Loss  10.060324668884277
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  3
# 	 Training accuracy:  98.04166666666667
# 	 Validation accuracy  61.71875
# 	 Test accuracy  71.625
# 	 Epoch Loss  8.42533016204834
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  4
# 	 Training accuracy:  99.91666666666667
# 	 Validation accuracy  67.1875
# 	 Test accuracy  73.25
# 	 Epoch Loss  4.7988972663879395
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  5
# 	 Training accuracy:  100.0
# 	 Validation accuracy  67.96875
# 	 Test accuracy  74.625
# 	 Epoch Loss  0.21112912893295288
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  6
# 	 Training accuracy:  100.0
# 	 Validation accuracy  68.75
# 	 Test accuracy  74.875
# 	 Epoch Loss  0.10998710244894028
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  7
# 	 Training accuracy:  100.0
# 	 Validation accuracy  68.75
# 	 Test accuracy  74.75
# 	 Epoch Loss  0.07914657145738602
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  8
# 	 Training accuracy:  100.0
# 	 Validation accuracy  67.96875
# 	 Test accuracy  75.0
# 	 Epoch Loss  0.06110544130206108
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  9
# 	 Training accuracy:  100.0
# 	 Validation accuracy  68.75
# 	 Test accuracy  75.0
# 	 Epoch Loss  0.04893152415752411
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  10
# 	 Training accuracy:  100.0
# 	 Validation accuracy  68.75
# 	 Test accuracy  75.0
# 	 Epoch Loss  0.04012679681181908
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  11
# 	 Training accuracy:  100.0
# 	 Validation accuracy  69.53125
# 	 Test accuracy  75.375
# 	 Epoch Loss  0.033457741141319275
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  12
# 	 Training accuracy:  100.0
# 	 Validation accuracy  69.53125
# 	 Test accuracy  75.625
# 	 Epoch Loss  0.028278252109885216
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  13
# 	 Training accuracy:  100.0
# 	 Validation accuracy  69.53125
# 	 Test accuracy  75.625
# 	 Epoch Loss  0.02415837161242962
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  14
# 	 Training accuracy:  100.0
# 	 Validation accuracy  69.53125
# 	 Test accuracy  75.875
# 	 Epoch Loss  0.02081887796521187
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  15
# 	 Training accuracy:  100.0
# 	 Validation accuracy  69.53125
# 	 Test accuracy  75.875
# 	 Epoch Loss  0.018067575991153717
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  16
# 	 Training accuracy:  100.0
# 	 Validation accuracy  69.53125
# 	 Test accuracy  75.75
# 	 Epoch Loss  0.01579122059047222
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  17
# 	 Training accuracy:  100.0
# 	 Validation accuracy  68.75
# 	 Test accuracy  75.875
# 	 Epoch Loss  0.01387729775160551
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  18
# 	 Training accuracy:  100.0
# 	 Validation accuracy  68.75
# 	 Test accuracy  76.0
# 	 Epoch Loss  0.012259909883141518
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  19
# 	 Training accuracy:  100.0
# 	 Validation accuracy  68.75
# 	 Test accuracy  76.25
# 	 Epoch Loss  0.010873816907405853
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  20
# 	 Training accuracy:  100.0
# 	 Validation accuracy  69.53125
# 	 Test accuracy  76.0
# 	 Epoch Loss  0.009681428782641888
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  21
# 	 Training accuracy:  100.0
# 	 Validation accuracy  69.53125
# 	 Test accuracy  76.0
# 	 Epoch Loss  0.008639617823064327
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  22
# 	 Training accuracy:  100.0
# 	 Validation accuracy  69.53125
# 	 Test accuracy  75.875
# 	 Epoch Loss  0.007730208802968264
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  23
# 	 Training accuracy:  100.0
# 	 Validation accuracy  69.53125
# 	 Test accuracy  75.875
# 	 Epoch Loss  0.0069313691928982735
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  24
# 	 Training accuracy:  100.0
# 	 Validation accuracy  70.3125
# 	 Test accuracy  75.75
# 	 Epoch Loss  0.006226750556379557
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  25
# 	 Training accuracy:  100.0
# 	 Validation accuracy  70.3125
# 	 Test accuracy  75.75
# 	 Epoch Loss  0.0056020584888756275
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  26
# 	 Training accuracy:  100.0
# 	 Validation accuracy  70.3125
# 	 Test accuracy  75.75
# 	 Epoch Loss  0.005047131329774857
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  27
# 	 Training accuracy:  100.0
# 	 Validation accuracy  70.3125
# 	 Test accuracy  75.5
# 	 Epoch Loss  0.0045571234077215195
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  28
# 	 Training accuracy:  100.0
# 	 Validation accuracy  70.3125
# 	 Test accuracy  75.5
# 	 Epoch Loss  0.004114758688956499
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  29
# 	 Training accuracy:  100.0
# 	 Validation accuracy  70.3125
# 	 Test accuracy  75.625
# 	 Epoch Loss  0.0037226579152047634
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  30
# 	 Training accuracy:  100.0
# 	 Validation accuracy  70.3125
# 	 Test accuracy  75.625
# 	 Epoch Loss  0.003369181649759412
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  31
# 	 Training accuracy:  100.0
# 	 Validation accuracy  70.3125
# 	 Test accuracy  75.875
# 	 Epoch Loss  0.003052622079849243
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  32
# 	 Training accuracy:  100.0
# 	 Validation accuracy  70.3125
# 	 Test accuracy  76.0
# 	 Epoch Loss  0.0027677728794515133
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  33
# 	 Training accuracy:  100.0
# 	 Validation accuracy  70.3125
# 	 Test accuracy  76.0
# 	 Epoch Loss  0.002510968130081892
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  34
# 	 Training accuracy:  100.0
# 	 Validation accuracy  70.3125
# 	 Test accuracy  75.875
# 	 Epoch Loss  0.0022776424884796143
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  35
# 	 Training accuracy:  100.0
# 	 Validation accuracy  70.3125
# 	 Test accuracy  75.75
# 	 Epoch Loss  0.00206868932582438
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  36
# 	 Training accuracy:  100.0
# 	 Validation accuracy  70.3125
# 	 Test accuracy  75.75
# 	 Epoch Loss  0.001880535390228033
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  37
# 	 Training accuracy:  100.0
# 	 Validation accuracy  70.3125
# 	 Test accuracy  75.75
# 	 Epoch Loss  0.0017092524794861674
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  38
# 	 Training accuracy:  100.0
# 	 Validation accuracy  70.3125
# 	 Test accuracy  75.875
# 	 Epoch Loss  0.0015545141650363803
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  39
# 	 Training accuracy:  100.0
# 	 Validation accuracy  70.3125
# 	 Test accuracy  76.0
# 	 Epoch Loss  0.001414097030647099
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  40
# 	 Training accuracy:  100.0
# 	 Validation accuracy  70.3125
# 	 Test accuracy  76.0
# 	 Epoch Loss  0.0012870205100625753
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  41
# 	 Training accuracy:  100.0
# 	 Validation accuracy  70.3125
# 	 Test accuracy  76.125
# 	 Epoch Loss  0.0011716997250914574
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  42
# 	 Training accuracy:  100.0
# 	 Validation accuracy  70.3125
# 	 Test accuracy  76.0
# 	 Epoch Loss  0.0010671295458450913
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  43
# 	 Training accuracy:  100.0
# 	 Validation accuracy  70.3125
# 	 Test accuracy  76.0
# 	 Epoch Loss  0.0009721496026031673
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  44
# 	 Training accuracy:  100.0
# 	 Validation accuracy  71.09375
# 	 Test accuracy  76.125
# 	 Epoch Loss  0.000886046327650547
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  45
# 	 Training accuracy:  100.0
# 	 Validation accuracy  71.09375
# 	 Test accuracy  76.0
# 	 Epoch Loss  0.0008080247789621353
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  46
# 	 Training accuracy:  100.0
# 	 Validation accuracy  71.09375
# 	 Test accuracy  76.0
# 	 Epoch Loss  0.0007370001403614879
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  47
# 	 Training accuracy:  100.0
# 	 Validation accuracy  71.09375
# 	 Test accuracy  76.0
# 	 Epoch Loss  0.0006725286948494613
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  48
# 	 Training accuracy:  100.0
# 	 Validation accuracy  71.09375
# 	 Test accuracy  75.875
# 	 Epoch Loss  0.0006140019395388663
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  49
# 	 Training accuracy:  100.0
# 	 Validation accuracy  71.09375
# 	 Test accuracy  75.875
# 	 Epoch Loss  0.0005605682963505387
# Repetition 1
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  0
# 	 Training accuracy:  87.45833333333333
# 	 Validation accuracy  70.3125
# 	 Test accuracy  66.0
# 	 Epoch Loss  96.88634490966797
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  1
# 	 Training accuracy:  94.0
# 	 Validation accuracy  66.40625
# 	 Test accuracy  68.75
# 	 Epoch Loss  30.11581039428711
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  2
# 	 Training accuracy:  89.5
# 	 Validation accuracy  60.15625
# 	 Test accuracy  70.375
# 	 Epoch Loss  19.790555953979492
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  3
# 	 Training accuracy:  99.75
# 	 Validation accuracy  64.84375
# 	 Test accuracy  71.875
# 	 Epoch Loss  16.790563583374023
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  4
# 	 Training accuracy:  100.0
# 	 Validation accuracy  71.09375
# 	 Test accuracy  72.625
# 	 Epoch Loss  1.1014004945755005
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  5
# 	 Training accuracy:  100.0
# 	 Validation accuracy  71.875
# 	 Test accuracy  72.5
# 	 Epoch Loss  0.25683626532554626
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  6
# 	 Training accuracy:  100.0
# 	 Validation accuracy  71.875
# 	 Test accuracy  72.25
# 	 Epoch Loss  0.16376130282878876
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  7
# 	 Training accuracy:  100.0
# 	 Validation accuracy  71.875
# 	 Test accuracy  72.375
# 	 Epoch Loss  0.11989947408437729
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  8
# 	 Training accuracy:  100.0
# 	 Validation accuracy  72.65625
# 	 Test accuracy  72.25
# 	 Epoch Loss  0.09215942770242691
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  9
# 	 Training accuracy:  100.0
# 	 Validation accuracy  73.4375
# 	 Test accuracy  72.75
# 	 Epoch Loss  0.07328543812036514
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  10
# 	 Training accuracy:  100.0
# 	 Validation accuracy  74.21875
# 	 Test accuracy  73.0
# 	 Epoch Loss  0.059583935886621475
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  11
# 	 Training accuracy:  100.0
# 	 Validation accuracy  74.21875
# 	 Test accuracy  72.875
# 	 Epoch Loss  0.04929580166935921
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  12
# 	 Training accuracy:  100.0
# 	 Validation accuracy  74.21875
# 	 Test accuracy  72.75
# 	 Epoch Loss  0.04133668914437294
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  13
# 	 Training accuracy:  100.0
# 	 Validation accuracy  75.0
# 	 Test accuracy  72.375
# 	 Epoch Loss  0.035045962780714035
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  14
# 	 Training accuracy:  100.0
# 	 Validation accuracy  75.78125
# 	 Test accuracy  72.5
# 	 Epoch Loss  0.029960935935378075
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  15
# 	 Training accuracy:  100.0
# 	 Validation accuracy  75.78125
# 	 Test accuracy  72.375
# 	 Epoch Loss  0.025819774717092514
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  16
# 	 Training accuracy:  100.0
# 	 Validation accuracy  76.5625
# 	 Test accuracy  72.25
# 	 Epoch Loss  0.022385045886039734
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  17
# 	 Training accuracy:  100.0
# 	 Validation accuracy  76.5625
# 	 Test accuracy  72.125
# 	 Epoch Loss  0.019511569291353226
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  18
# 	 Training accuracy:  100.0
# 	 Validation accuracy  76.5625
# 	 Test accuracy  72.125
# 	 Epoch Loss  0.017088524997234344
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  19
# 	 Training accuracy:  100.0
# 	 Validation accuracy  76.5625
# 	 Test accuracy  72.125
# 	 Epoch Loss  0.015026629902422428
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  20
# 	 Training accuracy:  100.0
# 	 Validation accuracy  76.5625
# 	 Test accuracy  72.125
# 	 Epoch Loss  0.013256060890853405
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  21
# 	 Training accuracy:  100.0
# 	 Validation accuracy  76.5625
# 	 Test accuracy  72.0
# 	 Epoch Loss  0.011732855811715126
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  22
# 	 Training accuracy:  100.0
# 	 Validation accuracy  76.5625
# 	 Test accuracy  72.125
# 	 Epoch Loss  0.010418152436614037
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  23
# 	 Training accuracy:  100.0
# 	 Validation accuracy  76.5625
# 	 Test accuracy  72.125
# 	 Epoch Loss  0.00927660521119833
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  24
# 	 Training accuracy:  100.0
# 	 Validation accuracy  76.5625
# 	 Test accuracy  72.25
# 	 Epoch Loss  0.00827158335596323
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  25
# 	 Training accuracy:  100.0
# 	 Validation accuracy  76.5625
# 	 Test accuracy  72.25
# 	 Epoch Loss  0.007398136891424656
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  26
# 	 Training accuracy:  100.0
# 	 Validation accuracy  76.5625
# 	 Test accuracy  72.25
# 	 Epoch Loss  0.006625720765441656
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  27
# 	 Training accuracy:  100.0
# 	 Validation accuracy  76.5625
# 	 Test accuracy  72.25
# 	 Epoch Loss  0.005944058299064636
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  28
# 	 Training accuracy:  100.0
# 	 Validation accuracy  76.5625
# 	 Test accuracy  72.25
# 	 Epoch Loss  0.005340096075087786
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  29
# 	 Training accuracy:  100.0
# 	 Validation accuracy  76.5625
# 	 Test accuracy  72.375
# 	 Epoch Loss  0.004804433789104223
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  30
# 	 Training accuracy:  100.0
# 	 Validation accuracy  76.5625
# 	 Test accuracy  72.375
# 	 Epoch Loss  0.004327571950852871
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  31
# 	 Training accuracy:  100.0
# 	 Validation accuracy  76.5625
# 	 Test accuracy  72.25
# 	 Epoch Loss  0.003902775701135397
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  32
# 	 Training accuracy:  100.0
# 	 Validation accuracy  76.5625
# 	 Test accuracy  72.25
# 	 Epoch Loss  0.0035228764172643423
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  33
# 	 Training accuracy:  100.0
# 	 Validation accuracy  76.5625
# 	 Test accuracy  72.0
# 	 Epoch Loss  0.003183471504598856
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  34
# 	 Training accuracy:  100.0
# 	 Validation accuracy  76.5625
# 	 Test accuracy  72.0
# 	 Epoch Loss  0.0028792263474315405
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  35
# 	 Training accuracy:  100.0
# 	 Validation accuracy  76.5625
# 	 Test accuracy  72.125
# 	 Epoch Loss  0.002606272930279374
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  36
# 	 Training accuracy:  100.0
# 	 Validation accuracy  76.5625
# 	 Test accuracy  72.375
# 	 Epoch Loss  0.002360663376748562
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  37
# 	 Training accuracy:  100.0
# 	 Validation accuracy  76.5625
# 	 Test accuracy  72.25
# 	 Epoch Loss  0.0021384521387517452
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  38
# 	 Training accuracy:  100.0
# 	 Validation accuracy  76.5625
# 	 Test accuracy  72.25
# 	 Epoch Loss  0.0019393638940528035
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  39
# 	 Training accuracy:  100.0
# 	 Validation accuracy  76.5625
# 	 Test accuracy  72.25
# 	 Epoch Loss  0.0017594435485079885
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  40
# 	 Training accuracy:  100.0
# 	 Validation accuracy  76.5625
# 	 Test accuracy  72.375
# 	 Epoch Loss  0.0015970385866239667
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  41
# 	 Training accuracy:  100.0
# 	 Validation accuracy  76.5625
# 	 Test accuracy  72.25
# 	 Epoch Loss  0.0014507482992485166
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  42
# 	 Training accuracy:  100.0
# 	 Validation accuracy  76.5625
# 	 Test accuracy  72.375
# 	 Epoch Loss  0.0013175634667277336
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  43
# 	 Training accuracy:  100.0
# 	 Validation accuracy  76.5625
# 	 Test accuracy  72.25
# 	 Epoch Loss  0.0011971700005233288
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  44
# 	 Training accuracy:  100.0
# 	 Validation accuracy  76.5625
# 	 Test accuracy  72.25
# 	 Epoch Loss  0.0010885766241699457
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  45
# 	 Training accuracy:  100.0
# 	 Validation accuracy  76.5625
# 	 Test accuracy  72.375
# 	 Epoch Loss  0.000989731284789741
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  46
# 	 Training accuracy:  100.0
# 	 Validation accuracy  76.5625
# 	 Test accuracy  72.5
# 	 Epoch Loss  0.0009008100023493171
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  47
# 	 Training accuracy:  100.0
# 	 Validation accuracy  76.5625
# 	 Test accuracy  72.5
# 	 Epoch Loss  0.0008197612478397787
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  48
# 	 Training accuracy:  100.0
# 	 Validation accuracy  76.5625
# 	 Test accuracy  72.5
# 	 Epoch Loss  0.0007460957858711481
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  49
# 	 Training accuracy:  100.0
# 	 Validation accuracy  76.5625
# 	 Test accuracy  72.5
# 	 Epoch Loss  0.000679441902320832
# Repetition 2
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  0
# 	 Training accuracy:  85.08333333333333
# 	 Validation accuracy  67.96875
# 	 Test accuracy  66.625
# 	 Epoch Loss  95.0806884765625
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  1
# 	 Training accuracy:  96.625
# 	 Validation accuracy  65.625
# 	 Test accuracy  66.25
# 	 Epoch Loss  33.905250549316406
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  2
# 	 Training accuracy:  94.29166666666667
# 	 Validation accuracy  71.09375
# 	 Test accuracy  76.875
# 	 Epoch Loss  15.668503761291504
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  3
# 	 Training accuracy:  97.625
# 	 Validation accuracy  66.40625
# 	 Test accuracy  76.25
# 	 Epoch Loss  12.991010665893555
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  4
# 	 Training accuracy:  99.75
# 	 Validation accuracy  63.28125
# 	 Test accuracy  71.25
# 	 Epoch Loss  4.756197452545166
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  5
# 	 Training accuracy:  99.95833333333333
# 	 Validation accuracy  64.84375
# 	 Test accuracy  71.5
# 	 Epoch Loss  0.45706459879875183
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  6
# 	 Training accuracy:  99.95833333333333
# 	 Validation accuracy  64.84375
# 	 Test accuracy  71.25
# 	 Epoch Loss  0.13133341073989868
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  7
# 	 Training accuracy:  100.0
# 	 Validation accuracy  64.84375
# 	 Test accuracy  71.25
# 	 Epoch Loss  0.09166223555803299
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  8
# 	 Training accuracy:  100.0
# 	 Validation accuracy  64.84375
# 	 Test accuracy  71.25
# 	 Epoch Loss  0.06949787586927414
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  9
# 	 Training accuracy:  100.0
# 	 Validation accuracy  64.84375
# 	 Test accuracy  71.25
# 	 Epoch Loss  0.0550166480243206
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  10
# 	 Training accuracy:  100.0
# 	 Validation accuracy  64.84375
# 	 Test accuracy  71.125
# 	 Epoch Loss  0.04473093897104263
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  11
# 	 Training accuracy:  100.0
# 	 Validation accuracy  64.84375
# 	 Test accuracy  70.625
# 	 Epoch Loss  0.03705746307969093
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  12
# 	 Training accuracy:  100.0
# 	 Validation accuracy  64.84375
# 	 Test accuracy  70.75
# 	 Epoch Loss  0.031152021139860153
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  13
# 	 Training accuracy:  100.0
# 	 Validation accuracy  64.84375
# 	 Test accuracy  70.75
# 	 Epoch Loss  0.026476914063096046
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  14
# 	 Training accuracy:  100.0
# 	 Validation accuracy  64.84375
# 	 Test accuracy  70.625
# 	 Epoch Loss  0.02270473726093769
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  15
# 	 Training accuracy:  100.0
# 	 Validation accuracy  64.84375
# 	 Test accuracy  70.75
# 	 Epoch Loss  0.01962050423026085
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  16
# 	 Training accuracy:  100.0
# 	 Validation accuracy  64.84375
# 	 Test accuracy  70.625
# 	 Epoch Loss  0.017058031633496284
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  17
# 	 Training accuracy:  100.0
# 	 Validation accuracy  64.84375
# 	 Test accuracy  70.875
# 	 Epoch Loss  0.014906244352459908
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  18
# 	 Training accuracy:  100.0
# 	 Validation accuracy  64.84375
# 	 Test accuracy  70.875
# 	 Epoch Loss  0.01308348122984171
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  19
# 	 Training accuracy:  100.0
# 	 Validation accuracy  64.84375
# 	 Test accuracy  71.125
# 	 Epoch Loss  0.011533382348716259
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  20
# 	 Training accuracy:  100.0
# 	 Validation accuracy  65.625
# 	 Test accuracy  71.25
# 	 Epoch Loss  0.010194338858127594
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  21
# 	 Training accuracy:  100.0
# 	 Validation accuracy  66.40625
# 	 Test accuracy  71.25
# 	 Epoch Loss  0.009045389480888844
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  22
# 	 Training accuracy:  100.0
# 	 Validation accuracy  66.40625
# 	 Test accuracy  71.25
# 	 Epoch Loss  0.00804184190928936
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  23
# 	 Training accuracy:  100.0
# 	 Validation accuracy  66.40625
# 	 Test accuracy  71.25
# 	 Epoch Loss  0.007175740785896778
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  24
# 	 Training accuracy:  100.0
# 	 Validation accuracy  66.40625
# 	 Test accuracy  71.125
# 	 Epoch Loss  0.006409947760403156
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  25
# 	 Training accuracy:  100.0
# 	 Validation accuracy  66.40625
# 	 Test accuracy  71.125
# 	 Epoch Loss  0.0057402984239161015
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  26
# 	 Training accuracy:  100.0
# 	 Validation accuracy  66.40625
# 	 Test accuracy  71.25
# 	 Epoch Loss  0.00515046576038003
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  27
# 	 Training accuracy:  100.0
# 	 Validation accuracy  66.40625
# 	 Test accuracy  71.125
# 	 Epoch Loss  0.004627721384167671
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  28
# 	 Training accuracy:  100.0
# 	 Validation accuracy  66.40625
# 	 Test accuracy  71.25
# 	 Epoch Loss  0.004165072925388813
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  29
# 	 Training accuracy:  100.0
# 	 Validation accuracy  66.40625
# 	 Test accuracy  71.25
# 	 Epoch Loss  0.0037566698156297207
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  30
# 	 Training accuracy:  100.0
# 	 Validation accuracy  66.40625
# 	 Test accuracy  71.25
# 	 Epoch Loss  0.0033895138185471296
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  31
# 	 Training accuracy:  100.0
# 	 Validation accuracy  66.40625
# 	 Test accuracy  71.25
# 	 Epoch Loss  0.003063768381252885
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  32
# 	 Training accuracy:  100.0
# 	 Validation accuracy  66.40625
# 	 Test accuracy  71.125
# 	 Epoch Loss  0.0027711051516234875
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  33
# 	 Training accuracy:  100.0
# 	 Validation accuracy  66.40625
# 	 Test accuracy  71.125
# 	 Epoch Loss  0.002509794430807233
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  34
# 	 Training accuracy:  100.0
# 	 Validation accuracy  66.40625
# 	 Test accuracy  71.125
# 	 Epoch Loss  0.0022744706366211176
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  35
# 	 Training accuracy:  100.0
# 	 Validation accuracy  66.40625
# 	 Test accuracy  71.25
# 	 Epoch Loss  0.002061703009530902
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  36
# 	 Training accuracy:  100.0
# 	 Validation accuracy  66.40625
# 	 Test accuracy  71.25
# 	 Epoch Loss  0.0018715491751208901
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# ...
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  40
# 	 Training accuracy:  100.0
# 	 Validation accuracy  70.3125
# 	 Test accuracy  73.875
# 	 Epoch Loss  0.0012204678496345878
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  41
# 	 Training accuracy:  100.0
# 	 Validation accuracy  70.3125
# 	 Test accuracy  74.125
# 	 Epoch Loss  0.001098928041756153
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  42
# 	 Training accuracy:  100.0
# 	 Validation accuracy  70.3125
# 	 Test accuracy  74.125
# 	 Epoch Loss  0.0009919892763718963
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  43
# 	 Training accuracy:  100.0
# 	 Validation accuracy  70.3125
# 	 Test accuracy  74.25
# 	 Epoch Loss  0.0008962680003605783
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  44
# 	 Training accuracy:  100.0
# 	 Validation accuracy  70.3125
# 	 Test accuracy  74.25
# 	 Epoch Loss  0.0008116427343338728
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  45
# 	 Training accuracy:  100.0
# 	 Validation accuracy  70.3125
# 	 Test accuracy  74.375
# 	 Epoch Loss  0.0007392066181637347
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  46
# 	 Training accuracy:  100.0
# 	 Validation accuracy  70.3125
# 	 Test accuracy  74.375
# 	 Epoch Loss  0.0006660952931270003
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  47
# 	 Training accuracy:  100.0
# 	 Validation accuracy  70.3125
# 	 Test accuracy  74.375
# 	 Epoch Loss  0.0006029470241628587
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  48
# 	 Training accuracy:  100.0
# 	 Validation accuracy  70.3125
# 	 Test accuracy  74.375
# 	 Epoch Loss  0.0005455256323330104
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  49
# 	 Training accuracy:  100.0
# 	 Validation accuracy  70.3125
# 	 Test accuracy  74.375
# 	 Epoch Loss  0.0004970467416569591
# Repetition 9
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  0
# 	 Training accuracy:  85.0
# 	 Validation accuracy  69.53125
# 	 Test accuracy  72.0
# 	 Epoch Loss  98.62106323242188
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  1
# 	 Training accuracy:  93.79166666666667
# 	 Validation accuracy  77.34375
# 	 Test accuracy  77.375
# 	 Epoch Loss  37.525230407714844
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  2
# 	 Training accuracy:  95.29166666666667
# 	 Validation accuracy  72.65625
# 	 Test accuracy  73.125
# 	 Epoch Loss  13.753512382507324
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  3
# 	 Training accuracy:  97.83333333333333
# 	 Validation accuracy  76.5625
# 	 Test accuracy  72.75
# 	 Epoch Loss  13.292160034179688
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  4
# 	 Training accuracy:  99.91666666666667
# 	 Validation accuracy  66.40625
# 	 Test accuracy  70.25
# 	 Epoch Loss  3.7102766036987305
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  5
# 	 Training accuracy:  99.95833333333333
# 	 Validation accuracy  66.40625
# 	 Test accuracy  71.125
# 	 Epoch Loss  0.28925591707229614
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  6
# 	 Training accuracy:  99.95833333333333
# 	 Validation accuracy  67.1875
# 	 Test accuracy  71.125
# 	 Epoch Loss  0.14984570443630219
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  7
# 	 Training accuracy:  99.95833333333333
# 	 Validation accuracy  67.1875
# 	 Test accuracy  70.875
# 	 Epoch Loss  0.10476299375295639
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  8
# 	 Training accuracy:  100.0
# 	 Validation accuracy  67.1875
# 	 Test accuracy  71.0
# 	 Epoch Loss  0.07838235050439835
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  9
# 	 Training accuracy:  100.0
# 	 Validation accuracy  67.1875
# 	 Test accuracy  71.0
# 	 Epoch Loss  0.0611078143119812
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  10
# 	 Training accuracy:  100.0
# 	 Validation accuracy  68.75
# 	 Test accuracy  70.875
# 	 Epoch Loss  0.049005284905433655
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  11
# 	 Training accuracy:  100.0
# 	 Validation accuracy  68.75
# 	 Test accuracy  71.0
# 	 Epoch Loss  0.04012608900666237
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  12
# 	 Training accuracy:  100.0
# 	 Validation accuracy  68.75
# 	 Test accuracy  71.0
# 	 Epoch Loss  0.03340234234929085
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  13
# 	 Training accuracy:  100.0
# 	 Validation accuracy  68.75
# 	 Test accuracy  71.0
# 	 Epoch Loss  0.02817218005657196
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  14
# 	 Training accuracy:  100.0
# 	 Validation accuracy  68.75
# 	 Test accuracy  71.25
# 	 Epoch Loss  0.024035684764385223
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  15
# 	 Training accuracy:  100.0
# 	 Validation accuracy  68.75
# 	 Test accuracy  71.25
# 	 Epoch Loss  0.020661944523453712
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  16
# 	 Training accuracy:  100.0
# 	 Validation accuracy  68.75
# 	 Test accuracy  71.375
# 	 Epoch Loss  0.0178715530782938
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  17
# 	 Training accuracy:  100.0
# 	 Validation accuracy  68.75
# 	 Test accuracy  71.5
# 	 Epoch Loss  0.015559909865260124
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  18
# 	 Training accuracy:  100.0
# 	 Validation accuracy  68.75
# 	 Test accuracy  71.0
# 	 Epoch Loss  0.013614668510854244
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  19
# 	 Training accuracy:  100.0
# 	 Validation accuracy  68.75
# 	 Test accuracy  71.0
# 	 Epoch Loss  0.011942507699131966
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  20
# 	 Training accuracy:  100.0
# 	 Validation accuracy  68.75
# 	 Test accuracy  71.0
# 	 Epoch Loss  0.010537346825003624
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  21
# 	 Training accuracy:  100.0
# 	 Validation accuracy  68.75
# 	 Test accuracy  71.0
# 	 Epoch Loss  0.009314621798694134
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  22
# 	 Training accuracy:  100.0
# 	 Validation accuracy  68.75
# 	 Test accuracy  71.125
# 	 Epoch Loss  0.008261576294898987
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  23
# 	 Training accuracy:  100.0
# 	 Validation accuracy  68.75
# 	 Test accuracy  71.25
# 	 Epoch Loss  0.0073417797684669495
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  24
# 	 Training accuracy:  100.0
# 	 Validation accuracy  68.75
# 	 Test accuracy  71.25
# 	 Epoch Loss  0.006544771604239941
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  25
# 	 Training accuracy:  100.0
# 	 Validation accuracy  68.75
# 	 Test accuracy  71.375
# 	 Epoch Loss  0.005844999570399523
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  26
# 	 Training accuracy:  100.0
# 	 Validation accuracy  68.75
# 	 Test accuracy  71.5
# 	 Epoch Loss  0.00522637739777565
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  27
# 	 Training accuracy:  100.0
# 	 Validation accuracy  68.75
# 	 Test accuracy  71.375
# 	 Epoch Loss  0.004684430081397295
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  28
# 	 Training accuracy:  100.0
# 	 Validation accuracy  68.75
# 	 Test accuracy  71.375
# 	 Epoch Loss  0.004204168915748596
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  29
# 	 Training accuracy:  100.0
# 	 Validation accuracy  68.75
# 	 Test accuracy  71.25
# 	 Epoch Loss  0.00377704668790102
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  30
# 	 Training accuracy:  100.0
# 	 Validation accuracy  68.75
# 	 Test accuracy  71.25
# 	 Epoch Loss  0.003399698529392481
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  31
# 	 Training accuracy:  100.0
# 	 Validation accuracy  68.75
# 	 Test accuracy  71.0
# 	 Epoch Loss  0.003061129944398999
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  32
# 	 Training accuracy:  100.0
# 	 Validation accuracy  68.75
# 	 Test accuracy  70.875
# 	 Epoch Loss  0.0027617611922323704
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  33
# 	 Training accuracy:  100.0
# 	 Validation accuracy  69.53125
# 	 Test accuracy  70.875
# 	 Epoch Loss  0.002492619212716818
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  34
# 	 Training accuracy:  100.0
# 	 Validation accuracy  69.53125
# 	 Test accuracy  70.875
# 	 Epoch Loss  0.002252867678180337
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])
# data_target torch.Size([128])
# data_input torch.Size([128, 1, 28, 62])
# data_target torch.Size([800])
# data_input torch.Size([800, 1, 28, 62])
# Epoch Number :  35
# 	 Training accuracy:  100.0
# 	 Validation accuracy  69.53125
# 	 Test accuracy  70.875
# 	 Epoch Loss  0.002037197817116976
# data_target torch.Size([2400])
# data_input torch.Size([2400, 1, 28, 62])

# %%
print(train_errors.shape)

for i_rep in range(Nrep):
    print(i_rep)
    plt.plot(np.array(train_errors[i_rep, :]))
    plt.plot(np.array(validation_errors[i_rep, :]))
    plt.plot(np.array(test_errors[i_rep, :]))
    plt.show()

# %%
for i_rep in range(Nrep):
    print(i_rep)
    plt.plot(100*(Ntrain-np.array(train_errors[i_rep, :]))/Ntrain)
    plt.plot(100*(Nvalidation-np.array(validation_errors[i_rep, :]))/Nvalidation)
    plt.plot(100*(Ntest-np.array(test_errors[i_rep, :]))/Ntest)

    plt.show()

# %%
train_accuracy = 100*(Ntrain-np.array(train_errors))/Ntrain
val_accuracy = 100*(Nvalidation-np.array(validation_errors))/Nvalidation
test_accuracy = 100*(Ntest-np.array(test_errors))/Ntest

stddev_train_errors = np.std(train_accuracy, axis=0)
stddev_val_errors = np.std(val_accuracy, axis=0)
stddev_test_errors = np.std(test_accuracy, axis=0)

mean_train_errors = np.mean(train_accuracy, axis=0)
mean_val_errors = np.mean(val_accuracy, axis=0)
mean_test_errors = np.mean(test_accuracy, axis=0)

epoch = list(range(50))
print(stddev_train_errors.shape)

#plt.errorbar(epoch, mean_train_errors, stddev_train_errors)
#plt.errorbar(epoch, mean_val_errors, stddev_val_errors)
#plt.errorbar(epoch, mean_test_errors, stddev_test_errors)

plt.plot(epoch, mean_train_errors)
plt.plot(epoch, mean_val_errors)
plt.plot(epoch, mean_test_errors)
plt.fill_between(epoch, mean_train_errors+stddev_train_errors, mean_train_errors-stddev_train_errors, alpha=0.5)
plt.fill_between(epoch, mean_val_errors+stddev_val_errors, mean_val_errors-stddev_val_errors, alpha=0.5)
plt.fill_between(epoch, mean_test_errors+stddev_test_errors, mean_test_errors-stddev_test_errors, alpha=0.5)
plt.xlabel('Number of epochs')
plt.ylabel('Accuracy in %')
plt.legend(['train', 'validation', 'test'])

print("Training accuracy {:4.3g}%+-{}".format(mean_train_errors[-1], stddev_train_errors[-1]))
print("Validation accuracy {:4.3g}%+-{}".format(mean_val_errors[-1], stddev_val_errors[-1]))
print("Testing accuracy {:4.3g}%+-{}".format(mean_test_errors[-1], stddev_test_errors[-1]))
