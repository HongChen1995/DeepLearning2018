# %%
import torch
from torch import Tensor
from torch import nn 
from torch.autograd import Variable
import torch.nn.functional as F
import numpy as np
from utility import *

np.random.seed(seed=7)

# %%
import dlc_bci

train_input_100 , train_target_100 = dlc_bci.load(root = './data_bci_100Hz', download = False)
test_input_100 , test_target_100 = dlc_bci.load(root = './data_bci_100Hz', download = False, train = False)

train_input_1000 , train_target_1000 = dlc_bci.load(root = './data_bci_1000Hz', download = False, one_khz = True)
test_input_1000 , test_target_1000 = dlc_bci.load(root = './data_bci_1000Hz', download = False, train = False, one_khz = True)

print("Train input 100 Hz: {:d}x{:d}x{:d}".format(*(s for s in train_input_100.size())))
print("Train target 100 Hz: {:d}".format(*(s for s in train_target_100.size())))
print("Test input 100 Hz: {:d}x{:d}x{:d}".format(*(s for s in test_input_100.size())))
print("Test target 100 Hz: {:d}".format(*(s for s in test_target_100.size())))
print("")
print("Train input 1000 Hz: {:d}x{:d}x{:d}".format(*(s for s in train_input_1000.size())))
print("Train target 1000 Hz: {:d}".format(*(s for s in train_target_1000.size())))
print("Test input 1000 Hz: {:d}x{:d}x{:d}".format(*(s for s in test_input_1000.size())))
print("Test target 1000 Hz: {:d}".format(*(s for s in test_target_1000.size())))
# Out:
# Train input 100 Hz: 316x28x50
# Train target 100 Hz: 316
# Test input 100 Hz: 100x28x50
# Test target 100 Hz: 100
#
# Train input 1000 Hz: 316x28x500
# Train target 1000 Hz: 316
# Test input 1000 Hz: 100x28x500
# Test target 1000 Hz: 100

# %% [markdown]
# # Network definition

# %% [markdown]
# This conv2d network is more inspired from a classic conv2d net that is used for image recognition

# %%
from models import *

# %%
def compute_nb_errors(model, data_input, data_target, batch_size):
    nb_errors = 0
    Ndata = len(data_input[:, 0, 0, 0])
    model.eval()
    print('data_target', data_target.shape)
    print('data_input', data_input.shape)
    
    for b_start in range(0, Ndata, batch_size):
        bsize_eff = batch_size - max(0, b_start+batch_size-Ndata)  # boundary case
        batch_output = model.forward(data_input.narrow(0, b_start, bsize_eff))  # is Variable if data_input is Variable
        if len(list(batch_output.size()))>1 and batch_output.size(1) > 1:
            # as many ouputs as there are classes => select maximum output
            nb_err_batch = (batch_output.max(1)[1] != data_target.narrow(0, b_start, bsize_eff)).long().sum()
            # overflow problem if conversion to Long Int not performed, treated as short 1-byte int otherwise!!
        else:
            # output is a scalar in [0, 1]
            nb_err_batch = batch_output.round().sub(data_target.narrow(0, b_start, bsize_eff)).sign().abs().sum()
        
        nb_errors += nb_err_batch
    if isinstance(nb_errors, Variable):
        nb_errors = nb_errors.data[0]
    return nb_errors

# %% [markdown]
# # Preprocessing and Data Augmentation

# %%
import numpy as np

preprocessed_input_train, preprocessed_input_validation, preprocessed_input_train_target, preprocessed_input_validation_target, kept_channels_idx = preprocessing_train(train_input_1000, train_target_1000, subsampling_frequency='100Hz', window=False,denoize=False, addGaussianNoise=False, reduceChannels=False, cutEnd = False)
preprocessed_input_test, preprocessed_input_test_target  = preprocessing_test(test_input_1000, test_target_1000, kept_channels_idx, subsampling_frequency='100Hz', window=False,denoize = False, reduceChannels=False, cutEnd=False)

#Remove Noise
#preprocessed_input_train = denoisedSignals(preprocessed_input_train)
#preprocessed_input_validation = denoisedSignals(preprocessed_input_validation)
#preprocessed_input_test = denoisedSignals(preprocessed_input_test)
#add random noise
#preprocessed_input_train = whiteNoise(preprocessed_input_train)
#preprocessed_input_validation = whiteNoise(preprocessed_input_validation)
#preprocessed_input_test = whiteNoise(preprocessed_input_test)

print('train', preprocessed_input_train.shape)
print('test', preprocessed_input_test.shape)
print('validation', preprocessed_input_validation.shape)

labels_train = torch.from_numpy(preprocessed_input_train_target)
labels_test = torch.from_numpy(preprocessed_input_test_target)
labels_validation = torch.from_numpy(preprocessed_input_validation_target)

preprocessed_input_train = torch.from_numpy(preprocessed_input_train).float()
preprocessed_input_test = torch.from_numpy(preprocessed_input_test).float()
preprocessed_input_validation = torch.from_numpy(preprocessed_input_validation).float()

Ntrain = len(preprocessed_input_train[:,0,0])
Ntest = len(preprocessed_input_test[:,0,0])
Nvalidation = len(preprocessed_input_validation[:,0,0])

Nchannels = len(preprocessed_input_train[0,:,0])
Nsamples_100 = preprocessed_input_train.size(-1)

print('Ntrain = ', Ntrain)
print('Ntest = ', Ntest)
print('Nvalidation = ', Nvalidation)

train_input = Variable(preprocessed_input_train.view(Ntrain, 1, Nchannels, Nsamples_100))
validation_input = Variable(preprocessed_input_validation.view(Nvalidation, 1, Nchannels, Nsamples_100), requires_grad=False)
test_input = Variable(preprocessed_input_test.contiguous().view(Ntest, 1, Nchannels, Nsamples_100), requires_grad=False)
# Out:
# train (3000, 28, 50)
# test (1000, 28, 50)
# validation (160, 28, 50)
# Ntrain =  3000
# Ntest =  1000
# Nvalidation =  160

# %% [markdown]
# # Network training and testing
# Non-linearity: elu
#
#
# |criterion | optimizer | lr  | momentum | batch size | Nepochs | Train acc. | Test acc.|
# |----------|-----------|-----|----------|------------|---------|------------|----------|
# | BCE  | Adam  |1e-1 | def. | 15 | 150 | 86.4 | 61.4 |
# | BCE  | Adam  |1e-1 | def. | 20 | 150 | 99.8 | 79.5 |
# | BCE  | SGD   | 1e-2 | 0.85 | 20 | 150 | 98.9  | 61.5 |
# | CE   | Adam  | 1e-2 | def. | 20 | 150 | 98.4  |  70.5 |
# | CE   | SGD   | 1e-2 | 0.85 | 20 | 150 | 99.1 | 75.1 |
#
#
# Non-linearity: ReLU

# %%
import torch.optim as optim
import math

# Train network 
criterion = nn.BCELoss()
#criterion = nn.CrossEntropyLoss()
#criterion = nn.PoissonNLLLoss()
#criterion = nn.BCEWithLogitsLoss()
#criterion = nn.SmoothL1Loss() #interesting ... but does not converge
#criterion = nn.MSELoss() #0.83 but unstable

if isinstance(criterion, nn.CrossEntropyLoss):
    train_target = Variable(labels_train)  # keep long tensors
    validation_target = Variable(labels_validation, requires_grad=False) # convert to float
    test_target = Variable(labels_test, requires_grad=False)
    Noutputs = 2
    
elif isinstance(criterion, nn.NLLLoss):
    train_target = Variable(labels_train)  # keep long tensors
    validation_target = Variable(labels_validation, requires_grad=False) # convert to float
    test_target = Variable(labels_test, requires_grad=False )
    Noutputs = 2
    
else:
    train_target = Variable(labels_train.float()) # convert to float
    validation_target = Variable(labels_validation.float(), requires_grad=False) # convert to float
    test_target = Variable(labels_test.float(), requires_grad=False)
    Noutputs = 1

batch_size = 15
Nbatches = int(math.ceil(Ntrain/batch_size))
Nepochs = 50
seeds = list(range(10))
#seeds = [14,20,21,22,27,46,44,37,31,28]
Nrep = len(seeds)

train_errors = torch.Tensor(Nrep, Nepochs).zero_()
test_errors = torch.Tensor(Nrep, Nepochs).zero_()
validation_errors = torch.Tensor(Nrep, Nepochs).zero_()
ep_loss = torch.Tensor(Nrep, Nepochs).zero_()

for i_rep in range(Nrep):
    
    print('Repetition', seeds[i_rep])
    torch.manual_seed(seeds[i_rep])
    #model = conv2DNet_1(Noutputs) #from classic knowledge of image segmentation  
    #model = conv2DNet_2(Nchannels, Nsamples_100, Noutputs) #from litterature 
    #model = conv2DNet_3(Noutputs) #from PdM
    #model = conv2DNet_4(Noutputs) #from PdM
    model = conv2DNet_5(Noutputs) #from PdM
    
    #optimizer = optim.SGD(model.parameters(), lr=1e-3, momentum=0.50)
    optimizer = optim.Adam(model.parameters())
    #optimizer = optim.Adagrad(model.parameters())
    #optimizer = optim.Adamax(model.parameters())
    #optimizer = optim.ASGD(model.parameters())
    #optimizer = optim.RMSprop(model.parameters())
    #optimizer = optim.Rprop(model.parameters())
    
    scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=10, verbose=True)

    for i_ep in range(Nepochs):
        for b_start in range(0, Ntrain, batch_size):
            bsize_eff = batch_size - max(0, b_start+batch_size-Ntrain)  # boundary case
            model.train()
            model.zero_grad()
            output = model(train_input.narrow(0, b_start, bsize_eff))
            batch_loss = criterion(output, train_target.narrow(0, b_start, bsize_eff))            
            ep_loss[i_rep, i_ep] += batch_loss.data[0]
            batch_loss.backward()
            optimizer.step()
        
        scheduler.step(ep_loss[i_rep, i_ep])
        
        nb_train_errs = compute_nb_errors(model, train_input, train_target, batch_size)
        nb_validation_errs = compute_nb_errors(model, validation_input, validation_target, batch_size)
        nb_test_errs = compute_nb_errors(model, test_input, test_target, batch_size)
        
        print("Epoch Number : ", i_ep)
        print("\t Training accuracy: ", (100*(Ntrain-nb_train_errs)/Ntrain))
        print("\t Validation accuracy ",(100*(Nvalidation-nb_validation_errs)/Nvalidation)) 
        print("\t Test accuracy ",(100*(Ntest-nb_test_errs)/Ntest))
        
        print("\t Epoch Loss ", ep_loss[i_rep, i_ep])
        
        train_errors[i_rep, i_ep] = nb_train_errs
        test_errors[i_rep, i_ep] = nb_test_errs
        validation_errors[i_rep, i_ep] = nb_validation_errs
# Out:
# Repetition 0
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  0
# 	 Training accuracy:  96.8
# 	 Validation accuracy  56.25
# 	 Test accuracy  69.9
# 	 Epoch Loss  84.3887710571289
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  1
# 	 Training accuracy:  92.6
# 	 Validation accuracy  57.5
# 	 Test accuracy  75.9
# 	 Epoch Loss  20.419967651367188
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  2
# 	 Training accuracy:  99.9
# 	 Validation accuracy  53.75
# 	 Test accuracy  72.2
# 	 Epoch Loss  9.975841522216797
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  3
# 	 Training accuracy:  100.0
# 	 Validation accuracy  53.75
# 	 Test accuracy  72.4
# 	 Epoch Loss  0.8164975643157959
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  4
# 	 Training accuracy:  100.0
# 	 Validation accuracy  56.25
# 	 Test accuracy  73.0
# 	 Epoch Loss  0.2837655544281006
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  5
# 	 Training accuracy:  100.0
# 	 Validation accuracy  58.125
# 	 Test accuracy  72.9
# 	 Epoch Loss  0.18008245527744293
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  6
# 	 Training accuracy:  100.0
# 	 Validation accuracy  60.0
# 	 Test accuracy  73.1
# 	 Epoch Loss  0.12634681165218353
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  7
# 	 Training accuracy:  100.0
# 	 Validation accuracy  62.5
# 	 Test accuracy  73.5
# 	 Epoch Loss  0.09330687671899796
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  8
# 	 Training accuracy:  100.0
# 	 Validation accuracy  63.75
# 	 Test accuracy  73.9
# 	 Epoch Loss  0.07137857377529144
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  9
# 	 Training accuracy:  100.0
# 	 Validation accuracy  64.375
# 	 Test accuracy  74.1
# 	 Epoch Loss  0.055974964052438736
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  10
# 	 Training accuracy:  100.0
# 	 Validation accuracy  65.0
# 	 Test accuracy  74.2
# 	 Epoch Loss  0.04480517655611038
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  11
# 	 Training accuracy:  100.0
# 	 Validation accuracy  65.625
# 	 Test accuracy  74.2
# 	 Epoch Loss  0.03639620542526245
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  12
# 	 Training accuracy:  100.0
# 	 Validation accuracy  65.625
# 	 Test accuracy  74.4
# 	 Epoch Loss  0.029974058270454407
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  13
# 	 Training accuracy:  100.0
# 	 Validation accuracy  65.625
# 	 Test accuracy  74.7
# 	 Epoch Loss  0.024905946105718613
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  14
# 	 Training accuracy:  100.0
# 	 Validation accuracy  65.0
# 	 Test accuracy  74.8
# 	 Epoch Loss  0.02088898979127407
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  15
# 	 Training accuracy:  100.0
# 	 Validation accuracy  65.0
# 	 Test accuracy  75.0
# 	 Epoch Loss  0.01765354350209236
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  16
# 	 Training accuracy:  100.0
# 	 Validation accuracy  65.0
# 	 Test accuracy  75.1
# 	 Epoch Loss  0.01499949861317873
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  17
# 	 Training accuracy:  100.0
# 	 Validation accuracy  64.375
# 	 Test accuracy  75.3
# 	 Epoch Loss  0.012820933945477009
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  18
# 	 Training accuracy:  100.0
# 	 Validation accuracy  64.375
# 	 Test accuracy  75.3
# 	 Epoch Loss  0.011015227064490318
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  19
# 	 Training accuracy:  100.0
# 	 Validation accuracy  64.375
# 	 Test accuracy  75.4
# 	 Epoch Loss  0.009504628367722034
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  20
# 	 Training accuracy:  100.0
# 	 Validation accuracy  64.375
# 	 Test accuracy  75.5
# 	 Epoch Loss  0.008223344571888447
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  21
# 	 Training accuracy:  100.0
# 	 Validation accuracy  64.375
# 	 Test accuracy  75.5
# 	 Epoch Loss  0.007146370131522417
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  22
# 	 Training accuracy:  100.0
# 	 Validation accuracy  64.375
# 	 Test accuracy  75.6
# 	 Epoch Loss  0.006220071576535702
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  23
# 	 Training accuracy:  100.0
# 	 Validation accuracy  64.375
# 	 Test accuracy  75.7
# 	 Epoch Loss  0.005433761980384588
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  24
# 	 Training accuracy:  100.0
# 	 Validation accuracy  64.375
# 	 Test accuracy  75.7
# 	 Epoch Loss  0.004755749832838774
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  25
# 	 Training accuracy:  100.0
# 	 Validation accuracy  64.375
# 	 Test accuracy  75.8
# 	 Epoch Loss  0.004166347905993462
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  26
# 	 Training accuracy:  100.0
# 	 Validation accuracy  64.375
# 	 Test accuracy  75.9
# 	 Epoch Loss  0.0036572294775396585
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  27
# 	 Training accuracy:  100.0
# 	 Validation accuracy  64.375
# 	 Test accuracy  75.9
# 	 Epoch Loss  0.003218328347429633
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  28
# 	 Training accuracy:  100.0
# 	 Validation accuracy  64.375
# 	 Test accuracy  76.0
# 	 Epoch Loss  0.002834845567122102
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  29
# 	 Training accuracy:  100.0
# 	 Validation accuracy  65.0
# 	 Test accuracy  76.2
# 	 Epoch Loss  0.002499943831935525
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  30
# 	 Training accuracy:  100.0
# 	 Validation accuracy  65.0
# 	 Test accuracy  76.4
# 	 Epoch Loss  0.002207420999184251
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  31
# 	 Training accuracy:  100.0
# 	 Validation accuracy  65.0
# 	 Test accuracy  76.4
# 	 Epoch Loss  0.001951478305272758
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  32
# 	 Training accuracy:  100.0
# 	 Validation accuracy  65.0
# 	 Test accuracy  76.4
# 	 Epoch Loss  0.001724929898045957
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  33
# 	 Training accuracy:  100.0
# 	 Validation accuracy  65.0
# 	 Test accuracy  76.4
# 	 Epoch Loss  0.0015276430640369654
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  34
# 	 Training accuracy:  100.0
# 	 Validation accuracy  65.0
# 	 Test accuracy  76.3
# 	 Epoch Loss  0.001354336622171104
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  35
# 	 Training accuracy:  100.0
# 	 Validation accuracy  65.0
# 	 Test accuracy  76.3
# 	 Epoch Loss  0.0011996208922937512
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  36
# 	 Training accuracy:  100.0
# 	 Validation accuracy  65.0
# 	 Test accuracy  76.4
# 	 Epoch Loss  0.0010650345357134938
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  37
# 	 Training accuracy:  100.0
# 	 Validation accuracy  65.0
# 	 Test accuracy  76.5
# 	 Epoch Loss  0.0009454839746467769
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  38
# 	 Training accuracy:  100.0
# 	 Validation accuracy  65.0
# 	 Test accuracy  76.5
# 	 Epoch Loss  0.0008400368969887495
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  39
# 	 Training accuracy:  100.0
# 	 Validation accuracy  65.0
# 	 Test accuracy  76.5
# 	 Epoch Loss  0.000746847246773541
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  40
# 	 Training accuracy:  100.0
# 	 Validation accuracy  65.0
# 	 Test accuracy  76.5
# 	 Epoch Loss  0.0006634150631725788
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  41
# 	 Training accuracy:  100.0
# 	 Validation accuracy  65.0
# 	 Test accuracy  76.6
# 	 Epoch Loss  0.0005902594421058893
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  42
# 	 Training accuracy:  100.0
# 	 Validation accuracy  65.0
# 	 Test accuracy  77.0
# 	 Epoch Loss  0.0005252975388430059
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  43
# 	 Training accuracy:  100.0
# 	 Validation accuracy  65.0
# 	 Test accuracy  77.1
# 	 Epoch Loss  0.0004674407246056944
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  44
# 	 Training accuracy:  100.0
# 	 Validation accuracy  65.0
# 	 Test accuracy  77.2
# 	 Epoch Loss  0.00041611894266679883
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  45
# 	 Training accuracy:  100.0
# 	 Validation accuracy  65.0
# 	 Test accuracy  77.2
# 	 Epoch Loss  0.0003708094300236553
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  46
# 	 Training accuracy:  100.0
# 	 Validation accuracy  65.0
# 	 Test accuracy  77.2
# 	 Epoch Loss  0.0003305738791823387
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  47
# 	 Training accuracy:  100.0
# 	 Validation accuracy  65.0
# 	 Test accuracy  77.4
# 	 Epoch Loss  0.0002942394057754427
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  48
# 	 Training accuracy:  100.0
# 	 Validation accuracy  65.0
# 	 Test accuracy  77.4
# 	 Epoch Loss  0.0002625519991852343
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  49
# 	 Training accuracy:  100.0
# 	 Validation accuracy  65.0
# 	 Test accuracy  77.4
# 	 Epoch Loss  0.00023405042884405702
# Repetition 1
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  0
# 	 Training accuracy:  96.26666666666667
# 	 Validation accuracy  58.75
# 	 Test accuracy  67.9
# 	 Epoch Loss  85.63520812988281
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  1
# 	 Training accuracy:  97.86666666666666
# 	 Validation accuracy  52.5
# 	 Test accuracy  69.9
# 	 Epoch Loss  19.063365936279297
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  2
# 	 Training accuracy:  99.9
# 	 Validation accuracy  55.0
# 	 Test accuracy  71.8
# 	 Epoch Loss  6.981106758117676
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  3
# 	 Training accuracy:  100.0
# 	 Validation accuracy  60.625
# 	 Test accuracy  73.6
# 	 Epoch Loss  0.5565477013587952
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  4
# 	 Training accuracy:  100.0
# 	 Validation accuracy  61.25
# 	 Test accuracy  74.2
# 	 Epoch Loss  0.21253524720668793
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  5
# 	 Training accuracy:  100.0
# 	 Validation accuracy  61.25
# 	 Test accuracy  74.4
# 	 Epoch Loss  0.139470174908638
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  6
# 	 Training accuracy:  100.0
# 	 Validation accuracy  63.125
# 	 Test accuracy  74.4
# 	 Epoch Loss  0.10057761520147324
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  7
# 	 Training accuracy:  100.0
# 	 Validation accuracy  64.375
# 	 Test accuracy  75.0
# 	 Epoch Loss  0.07591313868761063
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  8
# 	 Training accuracy:  100.0
# 	 Validation accuracy  64.375
# 	 Test accuracy  75.0
# 	 Epoch Loss  0.05907594785094261
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  9
# 	 Training accuracy:  100.0
# 	 Validation accuracy  65.625
# 	 Test accuracy  75.1
# 	 Epoch Loss  0.04708024114370346
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  10
# 	 Training accuracy:  100.0
# 	 Validation accuracy  66.875
# 	 Test accuracy  75.1
# 	 Epoch Loss  0.03818418085575104
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  11
# 	 Training accuracy:  100.0
# 	 Validation accuracy  66.875
# 	 Test accuracy  75.1
# 	 Epoch Loss  0.031387798488140106
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  12
# 	 Training accuracy:  100.0
# 	 Validation accuracy  66.875
# 	 Test accuracy  75.2
# 	 Epoch Loss  0.02609243243932724
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  13
# 	 Training accuracy:  100.0
# 	 Validation accuracy  67.5
# 	 Test accuracy  75.2
# 	 Epoch Loss  0.021883372217416763
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  14
# 	 Training accuracy:  100.0
# 	 Validation accuracy  66.875
# 	 Test accuracy  75.4
# 	 Epoch Loss  0.018495498225092888
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  15
# 	 Training accuracy:  100.0
# 	 Validation accuracy  66.875
# 	 Test accuracy  75.3
# 	 Epoch Loss  0.015727996826171875
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  16
# 	 Training accuracy:  100.0
# 	 Validation accuracy  66.25
# 	 Test accuracy  75.4
# 	 Epoch Loss  0.013455032370984554
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  17
# 	 Training accuracy:  100.0
# 	 Validation accuracy  66.875
# 	 Test accuracy  75.5
# 	 Epoch Loss  0.011561266146600246
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  18
# 	 Training accuracy:  100.0
# 	 Validation accuracy  66.875
# 	 Test accuracy  75.7
# 	 Epoch Loss  0.009977877140045166
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  19
# 	 Training accuracy:  100.0
# 	 Validation accuracy  66.875
# 	 Test accuracy  75.7
# 	 Epoch Loss  0.008638419210910797
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  20
# 	 Training accuracy:  100.0
# 	 Validation accuracy  66.875
# 	 Test accuracy  75.8
# 	 Epoch Loss  0.00750714959576726
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  21
# 	 Training accuracy:  100.0
# 	 Validation accuracy  66.875
# 	 Test accuracy  75.8
# 	 Epoch Loss  0.006539462134242058
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  22
# 	 Training accuracy:  100.0
# 	 Validation accuracy  66.875
# 	 Test accuracy  75.6
# 	 Epoch Loss  0.005710355471819639
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  23
# 	 Training accuracy:  100.0
# 	 Validation accuracy  66.875
# 	 Test accuracy  75.6
# 	 Epoch Loss  0.004998211283236742
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  24
# 	 Training accuracy:  100.0
# 	 Validation accuracy  66.875
# 	 Test accuracy  75.7
# 	 Epoch Loss  0.004383147694170475
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  25
# 	 Training accuracy:  100.0
# 	 Validation accuracy  66.875
# 	 Test accuracy  75.8
# 	 Epoch Loss  0.003850335255265236
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  26
# 	 Training accuracy:  100.0
# 	 Validation accuracy  66.875
# 	 Test accuracy  75.9
# 	 Epoch Loss  0.0033875799272209406
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  27
# 	 Training accuracy:  100.0
# 	 Validation accuracy  66.875
# 	 Test accuracy  76.0
# 	 Epoch Loss  0.0029860008507966995
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  28
# 	 Training accuracy:  100.0
# 	 Validation accuracy  66.875
# 	 Test accuracy  75.9
# 	 Epoch Loss  0.002634836360812187
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  29
# 	 Training accuracy:  100.0
# 	 Validation accuracy  66.875
# 	 Test accuracy  75.9
# 	 Epoch Loss  0.0023276072461158037
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  30
# 	 Training accuracy:  100.0
# 	 Validation accuracy  66.875
# 	 Test accuracy  75.9
# 	 Epoch Loss  0.002058499027043581
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  31
# 	 Training accuracy:  100.0
# 	 Validation accuracy  66.875
# 	 Test accuracy  75.9
# 	 Epoch Loss  0.0018231512513011694
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  32
# 	 Training accuracy:  100.0
# 	 Validation accuracy  66.875
# 	 Test accuracy  75.9
# 	 Epoch Loss  0.001614780048839748
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  33
# 	 Training accuracy:  100.0
# 	 Validation accuracy  66.875
# 	 Test accuracy  76.1
# 	 Epoch Loss  0.0014320346526801586
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  34
# 	 Training accuracy:  100.0
# 	 Validation accuracy  66.875
# 	 Test accuracy  76.1
# 	 Epoch Loss  0.001270896289497614
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  35
# 	 Training accuracy:  100.0
# 	 Validation accuracy  66.875
# 	 Test accuracy  76.1
# 	 Epoch Loss  0.0011281308252364397
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  36
# 	 Training accuracy:  100.0
# 	 Validation accuracy  66.875
# 	 Test accuracy  76.1
# 	 Epoch Loss  0.0010030500125139952
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  37
# 	 Training accuracy:  100.0
# 	 Validation accuracy  66.875
# 	 Test accuracy  76.1
# 	 Epoch Loss  0.0008913091151043773
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  38
# 	 Training accuracy:  100.0
# 	 Validation accuracy  66.875
# 	 Test accuracy  76.1
# 	 Epoch Loss  0.0007925692480057478
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  39
# 	 Training accuracy:  100.0
# 	 Validation accuracy  66.875
# 	 Test accuracy  76.1
# 	 Epoch Loss  0.000706060032825917
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  40
# 	 Training accuracy:  100.0
# 	 Validation accuracy  66.875
# 	 Test accuracy  76.1
# 	 Epoch Loss  0.000628259324003011
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  41
# 	 Training accuracy:  100.0
# 	 Validation accuracy  66.875
# 	 Test accuracy  76.1
# 	 Epoch Loss  0.0005598019924946129
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  42
# 	 Training accuracy:  100.0
# 	 Validation accuracy  66.875
# 	 Test accuracy  76.1
# 	 Epoch Loss  0.0004987752763554454
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  43
# 	 Training accuracy:  100.0
# 	 Validation accuracy  66.875
# 	 Test accuracy  76.1
# 	 Epoch Loss  0.0004448485851753503
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  44
# 	 Training accuracy:  100.0
# 	 Validation accuracy  66.875
# 	 Test accuracy  76.1
# 	 Epoch Loss  0.00039648840902373195
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  45
# 	 Training accuracy:  100.0
# 	 Validation accuracy  66.875
# 	 Test accuracy  76.1
# 	 Epoch Loss  0.0003538638702593744
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  46
# 	 Training accuracy:  100.0
# 	 Validation accuracy  66.875
# 	 Test accuracy  76.3
# 	 Epoch Loss  0.0003155642480123788
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  47
# 	 Training accuracy:  100.0
# 	 Validation accuracy  66.875
# 	 Test accuracy  76.3
# 	 Epoch Loss  0.00028171148733235896
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  48
# 	 Training accuracy:  100.0
# 	 Validation accuracy  66.875
# 	 Test accuracy  76.3
# 	 Epoch Loss  0.00025120802456513047
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  49
# 	 Training accuracy:  100.0
# 	 Validation accuracy  66.875
# 	 Test accuracy  76.3
# 	 Epoch Loss  0.00022441778855863959
# Repetition 2
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  0
# 	 Training accuracy:  96.5
# 	 Validation accuracy  70.0
# 	 Test accuracy  71.0
# 	 Epoch Loss  97.11222839355469
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  1
# 	 Training accuracy:  88.66666666666667
# 	 Validation accuracy  75.625
# 	 Test accuracy  69.8
# 	 Epoch Loss  22.531009674072266
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  2
# 	 Training accuracy:  97.16666666666667
# 	 Validation accuracy  73.75
# 	 Test accuracy  69.7
# 	 Epoch Loss  10.78005313873291
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  3
# 	 Training accuracy:  99.93333333333334
# 	 Validation accuracy  69.375
# 	 Test accuracy  75.5
# 	 Epoch Loss  5.157660961151123
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  4
# 	 Training accuracy:  100.0
# 	 Validation accuracy  73.125
# 	 Test accuracy  75.9
# 	 Epoch Loss  0.3333934247493744
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  5
# 	 Training accuracy:  100.0
# 	 Validation accuracy  73.125
# 	 Test accuracy  75.6
# 	 Epoch Loss  0.16005469858646393
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  6
# 	 Training accuracy:  100.0
# 	 Validation accuracy  73.125
# 	 Test accuracy  75.4
# 	 Epoch Loss  0.10843859612941742
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  7
# 	 Training accuracy:  100.0
# 	 Validation accuracy  73.75
# 	 Test accuracy  75.5
# 	 Epoch Loss  0.07970602065324783
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  8
# 	 Training accuracy:  100.0
# 	 Validation accuracy  74.375
# 	 Test accuracy  75.4
# 	 Epoch Loss  0.06134156510233879
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  9
# 	 Training accuracy:  100.0
# 	 Validation accuracy  75.0
# 	 Test accuracy  75.3
# 	 Epoch Loss  0.04874594509601593
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  10
# 	 Training accuracy:  100.0
# 	 Validation accuracy  75.0
# 	 Test accuracy  75.4
# 	 Epoch Loss  0.039565782994031906
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  11
# 	 Training accuracy:  100.0
# 	 Validation accuracy  75.0
# 	 Test accuracy  75.4
# 	 Epoch Loss  0.032603632658720016
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  12
# 	 Training accuracy:  100.0
# 	 Validation accuracy  75.0
# 	 Test accuracy  75.5
# 	 Epoch Loss  0.027163062244653702
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  13
# 	 Training accuracy:  100.0
# 	 Validation accuracy  75.625
# 	 Test accuracy  75.7
# 	 Epoch Loss  0.0228493120521307
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  14
# 	 Training accuracy:  100.0
# 	 Validation accuracy  75.625
# 	 Test accuracy  75.5
# 	 Epoch Loss  0.019349904730916023
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  15
# 	 Training accuracy:  100.0
# 	 Validation accuracy  75.625
# 	 Test accuracy  75.6
# 	 Epoch Loss  0.01648384891450405
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  16
# 	 Training accuracy:  100.0
# 	 Validation accuracy  75.625
# 	 Test accuracy  75.5
# 	 Epoch Loss  0.014121690765023232
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  17
# 	 Training accuracy:  100.0
# 	 Validation accuracy  75.625
# 	 Test accuracy  75.4
# 	 Epoch Loss  0.012146024033427238
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  18
# 	 Training accuracy:  100.0
# 	 Validation accuracy  75.625
# 	 Test accuracy  75.1
# 	 Epoch Loss  0.01048688217997551
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  19
# 	 Training accuracy:  100.0
# 	 Validation accuracy  75.625
# 	 Test accuracy  75.1
# 	 Epoch Loss  0.009074579924345016
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  20
# 	 Training accuracy:  100.0
# 	 Validation accuracy  75.625
# 	 Test accuracy  75.1
# 	 Epoch Loss  0.0078910356387496
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  21
# 	 Training accuracy:  100.0
# 	 Validation accuracy  75.625
# 	 Test accuracy  75.1
# 	 Epoch Loss  0.006868995726108551
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  22
# 	 Training accuracy:  100.0
# 	 Validation accuracy  75.625
# 	 Test accuracy  75.1
# 	 Epoch Loss  0.0060010263696312904
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  23
# 	 Training accuracy:  100.0
# 	 Validation accuracy  75.0
# 	 Test accuracy  75.1
# 	 Epoch Loss  0.005259288474917412
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  24
# 	 Training accuracy:  100.0
# 	 Validation accuracy  75.0
# 	 Test accuracy  75.2
# 	 Epoch Loss  0.004619930405169725
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  25
# 	 Training accuracy:  100.0
# 	 Validation accuracy  75.625
# 	 Test accuracy  75.2
# 	 Epoch Loss  0.0040716324001550674
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  26
# 	 Training accuracy:  100.0
# 	 Validation accuracy  75.625
# 	 Test accuracy  75.2
# 	 Epoch Loss  0.003593869274482131
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  27
# 	 Training accuracy:  100.0
# 	 Validation accuracy  75.625
# 	 Test accuracy  75.1
# 	 Epoch Loss  0.003178550163283944
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  28
# 	 Training accuracy:  100.0
# 	 Validation accuracy  76.25
# 	 Test accuracy  75.1
# 	 Epoch Loss  0.0028129436541348696
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  29
# 	 Training accuracy:  100.0
# 	 Validation accuracy  76.25
# 	 Test accuracy  75.2
# 	 Epoch Loss  0.002494548447430134
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  30
# 	 Training accuracy:  100.0
# 	 Validation accuracy  76.25
# 	 Test accuracy  75.2
# 	 Epoch Loss  0.002213649684563279
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  31
# 	 Training accuracy:  100.0
# 	 Validation accuracy  76.875
# 	 Test accuracy  75.2
# 	 Epoch Loss  0.001965885516256094
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  32
# 	 Training accuracy:  100.0
# 	 Validation accuracy  76.875
# 	 Test accuracy  75.1
# 	 Epoch Loss  0.001746902009472251
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  33
# 	 Training accuracy:  100.0
# 	 Validation accuracy  76.875
# 	 Test accuracy  75.2
# 	 Epoch Loss  0.0015536114806309342
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  34
# 	 Training accuracy:  100.0
# 	 Validation accuracy  76.875
# 	 Test accuracy  75.2
# 	 Epoch Loss  0.0013817489380016923
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  35
# 	 Training accuracy:  100.0
# 	 Validation accuracy  76.875
# 	 Test accuracy  75.2
# 	 Epoch Loss  0.0012298590736463666
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  36
# 	 Training accuracy:  100.0
# 	 Validation accuracy  76.875
# 	 Test accuracy  75.2
# 	 Epoch Loss  0.0010949335992336273
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  37
# 	 Training accuracy:  100.0
# 	 Validation accuracy  76.875
# 	 Test accuracy  75.3
# 	 Epoch Loss  0.0009747186559252441
# ...
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  40
# 	 Training accuracy:  100.0
# 	 Validation accuracy  67.5
# 	 Test accuracy  77.6
# 	 Epoch Loss  0.000724255049135536
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  41
# 	 Training accuracy:  100.0
# 	 Validation accuracy  67.5
# 	 Test accuracy  77.7
# 	 Epoch Loss  0.0006439858116209507
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  42
# 	 Training accuracy:  100.0
# 	 Validation accuracy  67.5
# 	 Test accuracy  77.6
# 	 Epoch Loss  0.0005746000679209828
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  43
# 	 Training accuracy:  100.0
# 	 Validation accuracy  67.5
# 	 Test accuracy  77.7
# 	 Epoch Loss  0.0005086250603199005
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  44
# 	 Training accuracy:  100.0
# 	 Validation accuracy  67.5
# 	 Test accuracy  78.2
# 	 Epoch Loss  0.00045192494872026145
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  45
# 	 Training accuracy:  100.0
# 	 Validation accuracy  68.125
# 	 Test accuracy  77.9
# 	 Epoch Loss  0.00040283441194333136
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  46
# 	 Training accuracy:  100.0
# 	 Validation accuracy  68.125
# 	 Test accuracy  77.9
# 	 Epoch Loss  0.00035536097129806876
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  47
# 	 Training accuracy:  100.0
# 	 Validation accuracy  68.125
# 	 Test accuracy  77.8
# 	 Epoch Loss  0.0003168222028762102
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  48
# 	 Training accuracy:  100.0
# 	 Validation accuracy  68.125
# 	 Test accuracy  78.0
# 	 Epoch Loss  0.00028260747785679996
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  49
# 	 Training accuracy:  100.0
# 	 Validation accuracy  68.125
# 	 Test accuracy  78.2
# 	 Epoch Loss  0.0002595014520920813
# Repetition 9
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  0
# 	 Training accuracy:  89.9
# 	 Validation accuracy  63.125
# 	 Test accuracy  67.0
# 	 Epoch Loss  96.72329711914062
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  1
# 	 Training accuracy:  83.56666666666666
# 	 Validation accuracy  65.625
# 	 Test accuracy  69.8
# 	 Epoch Loss  25.826475143432617
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  2
# 	 Training accuracy:  99.73333333333333
# 	 Validation accuracy  68.125
# 	 Test accuracy  74.8
# 	 Epoch Loss  12.481633186340332
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  3
# 	 Training accuracy:  100.0
# 	 Validation accuracy  68.75
# 	 Test accuracy  73.8
# 	 Epoch Loss  0.971396803855896
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  4
# 	 Training accuracy:  100.0
# 	 Validation accuracy  69.375
# 	 Test accuracy  74.6
# 	 Epoch Loss  0.3054156005382538
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  5
# 	 Training accuracy:  100.0
# 	 Validation accuracy  69.375
# 	 Test accuracy  75.3
# 	 Epoch Loss  0.18819789588451385
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  6
# 	 Training accuracy:  100.0
# 	 Validation accuracy  69.375
# 	 Test accuracy  75.6
# 	 Epoch Loss  0.13094736635684967
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  7
# 	 Training accuracy:  100.0
# 	 Validation accuracy  69.375
# 	 Test accuracy  75.7
# 	 Epoch Loss  0.09620891511440277
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  8
# 	 Training accuracy:  100.0
# 	 Validation accuracy  69.375
# 	 Test accuracy  76.0
# 	 Epoch Loss  0.0734030231833458
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  9
# 	 Training accuracy:  100.0
# 	 Validation accuracy  69.375
# 	 Test accuracy  76.1
# 	 Epoch Loss  0.05735856294631958
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  10
# 	 Training accuracy:  100.0
# 	 Validation accuracy  69.375
# 	 Test accuracy  76.4
# 	 Epoch Loss  0.04580361768603325
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  11
# 	 Training accuracy:  100.0
# 	 Validation accuracy  69.375
# 	 Test accuracy  76.4
# 	 Epoch Loss  0.037163324654102325
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  12
# 	 Training accuracy:  100.0
# 	 Validation accuracy  69.375
# 	 Test accuracy  76.5
# 	 Epoch Loss  0.03050880879163742
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  13
# 	 Training accuracy:  100.0
# 	 Validation accuracy  69.375
# 	 Test accuracy  76.9
# 	 Epoch Loss  0.0253351591527462
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  14
# 	 Training accuracy:  100.0
# 	 Validation accuracy  69.375
# 	 Test accuracy  77.2
# 	 Epoch Loss  0.021208444610238075
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  15
# 	 Training accuracy:  100.0
# 	 Validation accuracy  69.375
# 	 Test accuracy  77.1
# 	 Epoch Loss  0.01790059171617031
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  16
# 	 Training accuracy:  100.0
# 	 Validation accuracy  69.375
# 	 Test accuracy  77.2
# 	 Epoch Loss  0.015200338326394558
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  17
# 	 Training accuracy:  100.0
# 	 Validation accuracy  69.375
# 	 Test accuracy  77.4
# 	 Epoch Loss  0.0129733020439744
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  18
# 	 Training accuracy:  100.0
# 	 Validation accuracy  69.375
# 	 Test accuracy  77.5
# 	 Epoch Loss  0.011131742969155312
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  19
# 	 Training accuracy:  100.0
# 	 Validation accuracy  69.375
# 	 Test accuracy  77.5
# 	 Epoch Loss  0.009592315182089806
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  20
# 	 Training accuracy:  100.0
# 	 Validation accuracy  69.375
# 	 Test accuracy  77.5
# 	 Epoch Loss  0.008285688236355782
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  21
# 	 Training accuracy:  100.0
# 	 Validation accuracy  69.375
# 	 Test accuracy  77.7
# 	 Epoch Loss  0.007189850322902203
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  22
# 	 Training accuracy:  100.0
# 	 Validation accuracy  69.375
# 	 Test accuracy  77.6
# 	 Epoch Loss  0.0062492405995726585
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  23
# 	 Training accuracy:  100.0
# 	 Validation accuracy  69.375
# 	 Test accuracy  77.6
# 	 Epoch Loss  0.005447047296911478
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  24
# 	 Training accuracy:  100.0
# 	 Validation accuracy  69.375
# 	 Test accuracy  77.5
# 	 Epoch Loss  0.0047587016597390175
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  25
# 	 Training accuracy:  100.0
# 	 Validation accuracy  70.0
# 	 Test accuracy  77.5
# 	 Epoch Loss  0.00416672695428133
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  26
# 	 Training accuracy:  100.0
# 	 Validation accuracy  70.0
# 	 Test accuracy  77.7
# 	 Epoch Loss  0.0036491297651082277
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  27
# 	 Training accuracy:  100.0
# 	 Validation accuracy  70.0
# 	 Test accuracy  77.8
# 	 Epoch Loss  0.0032046816777437925
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  28
# 	 Training accuracy:  100.0
# 	 Validation accuracy  70.0
# 	 Test accuracy  77.8
# 	 Epoch Loss  0.0028143960516899824
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  29
# 	 Training accuracy:  100.0
# 	 Validation accuracy  70.0
# 	 Test accuracy  77.9
# 	 Epoch Loss  0.002478223294019699
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  30
# 	 Training accuracy:  100.0
# 	 Validation accuracy  70.0
# 	 Test accuracy  78.0
# 	 Epoch Loss  0.0021834918297827244
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  31
# 	 Training accuracy:  100.0
# 	 Validation accuracy  70.0
# 	 Test accuracy  78.0
# 	 Epoch Loss  0.0019236485240980983
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  32
# 	 Training accuracy:  100.0
# 	 Validation accuracy  70.0
# 	 Test accuracy  78.1
# 	 Epoch Loss  0.0016991030424833298
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  33
# 	 Training accuracy:  100.0
# 	 Validation accuracy  70.0
# 	 Test accuracy  78.2
# 	 Epoch Loss  0.001500002108514309
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  34
# 	 Training accuracy:  100.0
# 	 Validation accuracy  70.0
# 	 Test accuracy  78.3
# 	 Epoch Loss  0.001326580299064517
# data_target torch.Size([3000])
# data_input torch.Size([3000, 1, 28, 50])
# data_target torch.Size([160])
# data_input torch.Size([160, 1, 28, 50])
# data_target torch.Size([1000])
# data_input torch.Size([1000, 1, 28, 50])
# Epoch Number :  35
# 	 Training accuracy:  100.0
# 	 Validation accuracy  70.625
# 	 Test accuracy  78.4
# 	 Epoch Loss  0.0011723233619704843

# %%
print(train_errors.shape)

for i_rep in range(Nrep):
    print(i_rep)
    plt.plot(np.array(train_errors[i_rep, :]))
    plt.plot(np.array(validation_errors[i_rep, :]))
    plt.plot(np.array(test_errors[i_rep, :]))
    plt.show()

# %%
for i_rep in range(Nrep):
    print(i_rep)
    plt.plot(100*(Ntrain-np.array(train_errors[i_rep, :]))/Ntrain)
    plt.plot(100*(Nvalidation-np.array(validation_errors[i_rep, :]))/Nvalidation)
    plt.plot(100*(Ntest-np.array(test_errors[i_rep, :]))/Ntest)

    plt.show()

# %%
train_accuracy = 100*(Ntrain-np.array(train_errors))/Ntrain
val_accuracy = 100*(Nvalidation-np.array(validation_errors))/Nvalidation
test_accuracy = 100*(Ntest-np.array(test_errors))/Ntest

stddev_train_errors = np.std(train_accuracy, axis=0)
stddev_val_errors = np.std(val_accuracy, axis=0)
stddev_test_errors = np.std(test_accuracy, axis=0)

mean_train_errors = np.mean(train_accuracy, axis=0)
mean_val_errors = np.mean(val_accuracy, axis=0)
mean_test_errors = np.mean(test_accuracy, axis=0)

epoch = list(range(50))
print(stddev_train_errors.shape)

#plt.errorbar(epoch, mean_train_errors, stddev_train_errors)
#plt.errorbar(epoch, mean_val_errors, stddev_val_errors)
#plt.errorbar(epoch, mean_test_errors, stddev_test_errors)

plt.plot(epoch, mean_train_errors)
plt.plot(epoch, mean_val_errors)
plt.plot(epoch, mean_test_errors)
plt.fill_between(epoch, mean_train_errors+stddev_train_errors, mean_train_errors-stddev_train_errors, alpha=0.5)
plt.fill_between(epoch, mean_val_errors+stddev_val_errors, mean_val_errors-stddev_val_errors, alpha=0.5)
plt.fill_between(epoch, mean_test_errors+stddev_test_errors, mean_test_errors-stddev_test_errors, alpha=0.5)
plt.xlabel('Number of epochs')
plt.ylabel('Accuracy in %')
plt.legend(['train', 'validation', 'test'])

print("Training accuracy {:4.3g}%+-{}".format(mean_train_errors[-1], stddev_train_errors[-1]))
print("Validation accuracy {:4.3g}%+-{}".format(mean_val_errors[-1], stddev_val_errors[-1]))
print("Testing accuracy {:4.3g}%+-{}".format(mean_test_errors[-1], stddev_test_errors[-1]))
